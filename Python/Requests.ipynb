# %%
# reqeusts: HTTP 호출하는 프로그램 작성시 많이 사용되는 라이브러리
import requests

# %%
url='http://ecosia.com'
response=requests.get(url)

# %%
response.content
# Out:
# b'<!doctype html>\n<html data-n-head-ssr lang="en" data-n-head="%7B%22lang%22:%7B%22ssr%22:%22en%22%7D%7D">\n  <head >\n    <title>Ecosia - the search engine that plants trees</title><meta data-n-head="ssr" charset="utf-8"><meta data-n-head="ssr" name="viewport" content="width=device-width, initial-scale=1"><meta data-n-head="ssr" http-equiv="X-UA-Compatible" content="IE=edge"><meta data-n-head="ssr" name="theme-color" content="#2e747a"><meta data-n-head="ssr" name="referrer" content="origin-when-cross-origin"><meta data-n-head="ssr" name="keywords" content="ecosia, green, search, engine"><meta data-n-head="ssr" property="og:url" name="og:url" content="https://www.ecosia.org/"><meta data-n-head="ssr" property="og:image" name="og:image" content="https://cdn-static.ecosia.org/og/facebook.jpg"><meta data-n-head="ssr" data-hid="description" name="description" content="Ecosia uses the ad revenue from your searches to plant trees where they are needed the most. By searching with Ecosia, yo
# ...

# %%
response.text
# Out:
# '<!doctype html>\n<html data-n-head-ssr lang="en" data-n-head="%7B%22lang%22:%7B%22ssr%22:%22en%22%7D%7D">\n  <head >\n    <title>Ecosia - the search engine that plants trees</title><meta data-n-head="ssr" charset="utf-8"><meta data-n-head="ssr" name="viewport" content="width=device-width, initial-scale=1"><meta data-n-head="ssr" http-equiv="X-UA-Compatible" content="IE=edge"><meta data-n-head="ssr" name="theme-color" content="#2e747a"><meta data-n-head="ssr" name="referrer" content="origin-when-cross-origin"><meta data-n-head="ssr" name="keywords" content="ecosia, green, search, engine"><meta data-n-head="ssr" property="og:url" name="og:url" content="https://www.ecosia.org/"><meta data-n-head="ssr" property="og:image" name="og:image" content="https://cdn-static.ecosia.org/og/facebook.jpg"><meta data-n-head="ssr" data-hid="description" name="description" content="Ecosia uses the ad revenue from your searches to plant trees where they are needed the most. By searching with Ecosia, you
# ...

# %%
response.headers
# Out:
# {'Date': 'Fri, 31 Dec 2021 06:15:22 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'CF-Ray': '6c615f7b59d461d6-ICN', 'Accept-Ranges': 'none', 'Content-Encoding': 'gzip', 'ETag': '"15d02-ApIbpz4o3pGq9U2wX77lpYbeTkI"', 'Set-Cookie': 'ECFG=a=0:as=1:cs=0:dt=pc:f=i:fr=0:fs=1:l=en:lt=0:mc=en-us:nf=1:nt=0:pz=0:t=0:tt=na:tu=auto:wu=auto:ma=0; Domain=.ecosia.org; Path=/; Expires=Sat, 31 Dec 2022 06:15:22 GMT; SameSite=Lax, ECEI=randomly_generated_1294888672; Max-Age=2592000', 'Strict-Transport-Security': 'max-age=15552000; includeSubDomains', 'Vary': 'Accept-Encoding', 'CF-Cache-Status': 'DYNAMIC', 'Content-Security-Policy': "default-src 'self' *.ecosia.org data: *.sentry.io; script-src 'sha256-fEEPQR4/6h/APoZKIHiVqB5TgvHbFvVqQDTWV/4+rMc=' 'self' 'self' *.ecosia.org *.sentry.io dy1cy3yp6fd82.cloudfront.net; img-src 'self' *.ecosia.org s3.amazonaws.com data: ecosia-notifications.ghost.io; style-src 'self' *.ecosia.org 'unsafe-inlin
# ...

# %%
#json : getting the info you need

myJson={'John':30, 'Adrian': 29, 'new':{'a':1, 'b':2, 'c':3}}

# %%
currencyURL = 'https://api.exchangerate-api.com/v4/latest/USD'
response=requests.get(currencyURL)

# %%
data=response.json()

# %%
data['rates']
# Out:
# {'USD': 1,
#  'AED': 3.67,
#  'AFN': 103.26,
#  'ALL': 106.15,
#  'AMD': 484.42,
#  'ANG': 1.79,
#  'AOA': 556.24,
#  'ARS': 102.55,
#  'AUD': 1.38,
#  'AWG': 1.79,
#  'AZN': 1.7,
#  'BAM': 1.73,
#  'BBD': 2,
#  'BDT': 85.49,
#  'BGN': 1.73,
#  'BHD': 0.376,
#  'BIF': 1992.48,
#  'BMD': 1,
#  'BND': 1.35,
#  'BOB': 6.87,
#  'BRL': 5.64,
#  'BSD': 1,
#  'BTN': 74.44,
#  'BWP': 11.74,
#  'BYN': 2.55,
#  'BZD': 2,
#  'CAD': 1.28,
#  'CDF': 1972.98,
#  'CHF': 0.915,
#  'CLP': 848.7,
#  'CNY': 6.37,
#  'COP': 4028.56,
#  'CRC': 639.6,
#  'CUC': 1,
#  'CUP': 25,
#  'CVE': 97.42,
#  'CZK': 22.04,
#  'DJF': 177.72,
#  'DKK': 6.59,
#  'DOP': 56.74,
#  'DZD': 138.99,
#  'EGP': 15.69,
#  'ERN': 15,
#  'ETB': 49.44,
#  'EUR': 0.884,
#  'FJD': 2.11,
#  'FKP': 0.742,
#  'FOK': 6.59,
#  'GBP': 0.742,
#  'GEL': 3.1,
#  'GGP': 0.742,
#  'GHS': 6.32,
#  'GIP': 0.742,
#  'GMD': 52.83,
#  'GNF': 9451.07,
#  'GTQ': 7.69,
#  'GYD': 209.13,
#  'HKD': 7.8,
#  'HNL': 24.41,
#  'HRK': 6.66,
#  'HTG': 100.98,
# ...
